# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("./ElectricCarData.csv")

# %%
data = data.drop('Segment',axis=1)

# %%
data.head()
# Out:
#    Unnamed: 0        Brand                          Model     Accel  TopSpeed  \
# 0           0       Tesla   Model 3 Long Range Dual Motor   4.6 sec  233 km/h
# 1           1  Volkswagen                       ID.3 Pure  10.0 sec  160 km/h
# 2           2    Polestar                               2   4.7 sec  210 km/h
# 3           3         BMW                            iX3    6.8 sec  180 km/h
# 4           4       Honda                              e    9.5 sec  145 km/h
#
#     Range Efficiency FastCharge              RapidCharge        PowerTrain  \
# 0  450 km  161 Wh/km   940 km/h  Rapid charging possible   All Wheel Drive
# 1  270 km  167 Wh/km   250 km/h  Rapid charging possible  Rear Wheel Drive
# 2  400 km  181 Wh/km   620 km/h  Rapid charging possible   All Wheel Drive
# 3  360 km  206 Wh/km   560 km/h  Rapid charging possible  Rear Wheel Drive
# 4  170 km  168 Wh/km   190 km/h  Rapid charging possible  Rear Wheel Drive
#
#      PlugType  BodyStyle  Seats  PriceEuro
# ...

# %%
data['Brand'].value_counts()
data['Range'].value_counts()
# Out:
# 400 km    6
# 250 km    6
# 365 km    5
# 425 km    4
# 450 km    4
# 440 km    3
# 420 km    3
# 325 km    3
# 195 km    3
# 375 km    3
# 255 km    3
# 390 km    3
# 335 km    3
# 340 km    3
# 170 km    2
# 230 km    2
# 220 km    2
# 370 km    2
# 320 km    2
# 235 km    2
# 410 km    2
# 330 km    2
# 275 km    2
# 190 km    2
# 350 km    2
# 270 km    2
# 95 km     2
# 310 km    2
# 360 km    2
# 280 km    1
# 575 km    1
# 515 km    1
# 185 km    1
# 180 km    1
# 435 km    1
# 160 km    1
# 385 km    1
# 430 km    1
# 290 km    1
# 295 km    1
# 225 km    1
# 315 km    1
# 750 km    1
# 970 km    1
# 610 km    1
# 100 km    1
# 460 km    1
# 505 km    1
# 130 km    1
# 380 km    1
# Name: Range, dtype: int64

# %%
plt.rcParams['figure.figsize'] = (100, 8)
f = sns.countplot(x=data['Range'],palette = 'hsv')
f.bar_label(f.containers[0])
plt.title('Range distributions of cars')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-d7871d90e980> in <module>
#       1 plt.rcParams['figure.figsize'] = (100, 8)
#       2 f = sns.countplot(x=data['Range'],palette = 'hsv')
# ----> 3 f.bar_label(f.containers[0])
#       4 plt.title('Range distributions of cars')
#       5 plt.show()
#
# AttributeError: 'AxesSubplot' object has no attribute 'bar_label'

# %%
data.isnull().any()

# %%
data['Model'].unique()

# %%
data['Accel'].unique()

# %%
data['TopSpeed'].unique()

# %%
data['Range'].unique()

# %%
data['Efficiency'].unique()
# Out:
# array(['161 Wh/km', '167 Wh/km', '181 Wh/km', '206 Wh/km', '168 Wh/km',
#        '180 Wh/km', '164 Wh/km', '153 Wh/km', '193 Wh/km', '216 Wh/km',
#        '160 Wh/km', '178 Wh/km', '175 Wh/km', '223 Wh/km', '166 Wh/km',
#        '156 Wh/km', '171 Wh/km', '179 Wh/km', '197 Wh/km', '183 Wh/km',
#        '200 Wh/km', '231 Wh/km', '173 Wh/km', '165 Wh/km', '267 Wh/km',
#        '172 Wh/km', '184 Wh/km', '154 Wh/km', '228 Wh/km', '195 Wh/km',
#        '104 Wh/km', '188 Wh/km', '237 Wh/km', '176 Wh/km', '211 Wh/km',
#        '177 Wh/km', '198 Wh/km', '232 Wh/km', '261 Wh/km', '194 Wh/km',
#        '209 Wh/km', '217 Wh/km', '244 Wh/km', '215 Wh/km', '273 Wh/km',
#        '256 Wh/km', '219 Wh/km', '270 Wh/km', '207 Wh/km', '170 Wh/km',
#        '222 Wh/km', '191 Wh/km', '258 Wh/km', '238 Wh/km'], dtype=object)

# %%
data['FastCharge'].unique()
# Out:
# array(['940 km/h', '250 km/h', '620 km/h', '560 km/h', '190 km/h',
#        '220 km/h', '420 km/h', '650 km/h', '540 km/h', '440 km/h',
#        '230 km/h', '380 km/h', '210 km/h', '590 km/h', '780 km/h',
#        '170 km/h', '260 km/h', '930 km/h', '850 km/h', '910 km/h',
#        '490 km/h', '470 km/h', '270 km/h', '450 km/h', '350 km/h',
#        '710 km/h', '240 km/h', '390 km/h', '570 km/h', '610 km/h',
#        '340 km/h', '730 km/h', '920 km/h', '-', '550 km/h', '900 km/h',
#        '520 km/h', '430 km/h', '890 km/h', '410 km/h', '770 km/h',
#        '460 km/h', '360 km/h', '810 km/h', '480 km/h', '290 km/h',
#        '330 km/h', '740 km/h', '510 km/h', '320 km/h', '500 km/h'],
#       dtype=object)

# %%
data['RapidCharge'].unique()
# Out:
# array(['Rapid charging possible', 'Rapid charging not possible'],
#       dtype=object)

# %%
data['PowerTrain'].unique()
# Out:
# array(['All Wheel Drive', 'Rear Wheel Drive', 'Front Wheel Drive'],
#       dtype=object)

# %%
data['PlugType'].unique()
# Out:
# array(['Type 2 CCS', 'Type 2 CHAdeMO', 'Type 2', 'Type 1 CHAdeMO'],
#       dtype=object)

# %%
data['BodyStyle'].unique()
# Out:
# array(['Sedan', 'Hatchback', 'Liftback', 'SUV', 'Pickup', 'MPV', 'Cabrio',
#        'SPV', 'Station'], dtype=object)

# %%
data['Seats'].unique()
# Out:
# array([5, 4, 7, 6, 2], dtype=int64)

# %%
data['PriceEuro'].unique()
# Out:
# array([ 55480,  30000,  56440,  68040,  32997, 105000,  31900,  29682,
#         46380,  55000,  69484,  29234,  40795,  65000,  34459,  40936,
#        180781,  21421,  31681,  29146,  58620,  35000, 125000,  61480,
#         45000,  33000,  60437,  38017,  34361,  67358,  38105,  31184,
#         75000,  32646,  37237,  50000,  33133,  79990,  33971,  81639,
#         24534,  20129,  36837,  41906, 102945, 149000,  36057,  79445,
#        215000,  40000,  85990,  35921,  37422,  24790,  96990,  65620,
#         75351,  54475, 109302,  33246,  38000,  62900,  41526, 150000,
#         64000,  25500,  34400,  57500,  22030,  54000, 148301,  38987,
#        102990,  21387,  46900,  70631,  34900,  69551,  47500,  37500,
#         93800,  24565,  37900,  35575,  53500,  96050,  62000],
#       dtype=int64)

# %%
sns.pairplot(data)
plt.show()

# %%
plt.figure(figsize=[10,10])
data['RapidCharge'].value_counts().plot.pie(autopct='%.0f%%')
plt.show()

# %%
plt.figure(figsize=[10,10])
data['PowerTrain'].value_counts().plot.pie(autopct='%.0f%%')
plt.show()

# %%
plt.figure(figsize=[15,15])
data['PlugType'].value_counts().plot.pie(autopct='%.0f%%')
plt.show()

# %%
plt.figure(figsize=[25,25])
data['BodyStyle'].value_counts().plot.pie(autopct='%.0f%%')
plt.show()

# %%
plt.figure(figsize=[25,25])
data['Seats'].value_counts().plot.pie(autopct='%.0f%%')
plt.show()

# %%
def convert_float(x):
    return(float(x[:-4]))
data['Accel'] = data['Accel'].apply(convert_float)

# %%
def convert_float(x):
    return(float(x[:-5]))
data['TopSpeed'] = data['TopSpeed'].apply(convert_float)

# %%
def convert_float(x):
    return(float(x[:-3]))
data['Range'] = data['Range'].apply(convert_float)

# %%
def convert_float(x):
    return(float(x[:-6]))
data['Efficiency'] = data['Efficiency'].apply(convert_float)

# %%
def convert_float(x):
    try:
        return(float(x[:-5]))
    except:
        return 0
data['FastCharge'] = data['FastCharge'].apply(convert_float)

# %%
data['RapidCharge'].unique()
# Out:
# array(['Rapid charging possible', 'Rapid charging not possible'],
#       dtype=object)

# %%
data['RapidCharge']=data['RapidCharge'].replace(to_replace='Rapid charging possible',value=1)
data['RapidCharge']=data['RapidCharge'].replace(to_replace='Rapid charging not possible',value=0)

# %%
data_bool=pd.get_dummies(data.drop(['Brand','Model'],axis=1),drop_first=False)

# %%
data_bool
# Out:
#      Unnamed: 0  Accel  TopSpeed  Range  Efficiency  FastCharge  RapidCharge  \
# 0             0    4.6     233.0  450.0       161.0       940.0            1
# 1             1   10.0     160.0  270.0       167.0       250.0            1
# 2             2    4.7     210.0  400.0       181.0       620.0            1
# 3             3    6.8     180.0  360.0       206.0       560.0            1
# 4             4    9.5     145.0  170.0       168.0       190.0            1
# ..          ...    ...       ...    ...         ...         ...          ...
# 98           98    7.5     160.0  330.0       191.0       440.0            1
# 99           99    4.5     210.0  335.0       258.0       540.0            1
# 100         100    5.9     200.0  325.0       194.0       440.0            1
# 101         101    5.1     200.0  375.0       232.0       450.0            1
# 102         102    7.5     190.0  400.0       238.0       480.0            1
#
# ...

# %%
from sklearn.decomposition import PCA

# %%
pd.options.display.float_format = '{:.6f}'.format
pca = PCA(n_components=11)
pca.fit(data_bool)
pca_data = pca.transform(data_bool)
df = pd.DataFrame(pca_data)
df.describe()
# Out:
#                  0           1           2          3          4          5   \
# count    103.000000  103.000000  103.000000 103.000000 103.000000 103.000000
# mean      -0.000000   -0.000000    0.000000  -0.000000   0.000000   0.000000
# std    34135.099255  175.538866   73.328383  33.436223  21.799324  19.778821
# min   -35683.649993 -384.833725 -190.888546 -77.609649 -57.823146 -59.436871
# 25%   -21382.971612 -123.140381  -45.429523 -23.884000 -12.043829  -9.790097
# 50%   -10810.844301   -7.222156   -1.910091   1.869526   0.867064   1.103745
# 75%     9189.021022   83.953623   38.736103  26.277328  13.453028   8.825463
# max   159190.294188  516.721114  289.084469  84.570399  73.749981 111.984623
#
#               6          7          8          9          10
# count 103.000000 103.000000 103.000000 103.000000 103.000000
# mean   -0.000000  -0.000000   0.000000   0.000000  -0.000000
# std     1.640469   0.769168   0.528553   0.490993   0.398258
# ...

# %%
loadings = pd.DataFrame(pca.components_.T, columns=df.columns, index=data_bool.columns)
loadings
# Out:
#                                     0         1         2         3   \
# Unnamed: 0                    0.000038 -0.031146  0.000674 -0.775424
# Accel                        -0.000055 -0.008608 -0.000403  0.004945
# TopSpeed                      0.001058  0.080628  0.031371 -0.008693
# Range                         0.002491  0.359564  0.931168 -0.001983
# Efficiency                    0.000344  0.013496  0.004563 -0.631122
# FastCharge                    0.004240  0.928955 -0.363198 -0.015247
# RapidCharge                   0.000001  0.000545  0.000246  0.000528
# Seats                         0.000000  0.001660  0.002056 -0.004657
# PriceEuro                     0.999987 -0.004924 -0.000815  0.000325
# PowerTrain_All Wheel Drive    0.000010  0.000728 -0.000160 -0.002887
# PowerTrain_Front Wheel Drive -0.000006 -0.000779  0.000283  0.002457
# PowerTrain_Rear Wheel Drive  -0.000003  0.000051 -0.000123  0.000430
# PlugType_Type 1 CHAdeMO      -0.000000 -0.000056 -0.000060 -0.000187
# ...

# %%
plt.rcParams['figure.figsize'] = (20,10)
sns.scatterplot(x=pca_data[:,0],y=pca_data[:,1],s=1000,hue=data['PriceEuro'])
plt.xlabel("PC1")
plt.ylabel("PC2")
# Out:
# Text(0, 0.5, 'PC2')

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = scaler.fit_transform(data_bool)

# %%
import warnings
warnings.filterwarnings('ignore')
X=data_bool
ssd = []
from sklearn.cluster import KMeans
for k in range(2,10):
    model = KMeans(n_clusters=k,n_init=10)
    model.fit(X)
    ssd.append(model.inertia_)

# %%
plt.plot(range(2,10),ssd,'o--')
plt.xlabel("K Value")
plt.ylabel(" Sum of Squared Distances")
# Out:
# Text(0, 0.5, ' Sum of Squared Distances')

# %%
from sklearn.metrics import silhouette_score
silhouette_coefficients = []
for k in range(2, 10):
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(X)
    score = silhouette_score(X, kmeans.labels_)
    silhouette_coefficients.append(score)

# %%
plt.plot(range(2,10),silhouette_coefficients,'o--')
plt.xlabel("K Value")
plt.ylabel("Silhouette Score")
# Out:
# Text(0, 0.5, 'Silhouette Score')

# %%
from sklearn.datasets import make_moons
features, true_labels = make_moons(n_samples=len(data_bool), noise=0.05)

# %%
from sklearn.metrics import adjusted_rand_score
from sklearn.metrics import adjusted_mutual_info_score
ari = []
for k in range(2, 10):
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(X)
    score = adjusted_rand_score(true_labels, kmeans.labels_)
    ari.append(score)

# %%
plt.plot(range(2,10),ari,'o--')
plt.xlabel("K Value")
plt.ylabel("Adjusted Random Index Score")
# Out:
# Text(0, 0.5, 'Adjusted Random Index Score')

# %%
final_kmeans = KMeans(n_clusters=5)
final_kmeans.fit(X)
# Out:
# KMeans(n_clusters=5)

# %%
data_bool["Cluster"]=final_kmeans.labels_

# %%
data_bool
# Out:
#      Unnamed: 0     Accel   TopSpeed      Range  Efficiency  FastCharge  \
# 0             0  4.600000 233.000000 450.000000  161.000000  940.000000
# 1             1 10.000000 160.000000 270.000000  167.000000  250.000000
# 2             2  4.700000 210.000000 400.000000  181.000000  620.000000
# 3             3  6.800000 180.000000 360.000000  206.000000  560.000000
# 4             4  9.500000 145.000000 170.000000  168.000000  190.000000
# ..          ...       ...        ...        ...         ...         ...
# 98           98  7.500000 160.000000 330.000000  191.000000  440.000000
# 99           99  4.500000 210.000000 335.000000  258.000000  540.000000
# 100         100  5.900000 200.000000 325.000000  194.000000  440.000000
# 101         101  5.100000 200.000000 375.000000  232.000000  450.000000
# 102         102  7.500000 190.000000 400.000000  238.000000  480.000000
#
#      RapidCharge  Seats  PriceEuro  PowerTrain_All Wheel Drive  ...  \
# ...

# %%
segement_profile = data_bool.groupby("Cluster").aggregate('mean')

# %%
segement_profile
# Out:
#          Unnamed: 0    Accel   TopSpeed      Range  Efficiency  FastCharge  \
# Cluster
# 0         49.086207 9.124138 153.344828 274.741379  174.034483  316.896552
# 1         57.454545 4.081818 234.636364 428.181818  214.909091  597.272727
# 2         33.500000 2.450000 335.000000 672.500000  214.500000  850.000000
# 3         53.035714 5.807143 193.285714 397.500000  209.428571  540.714286
# 4         55.500000 5.050000 225.000000 443.750000  183.250000  742.500000
#
#          RapidCharge    Seats     PriceEuro  PowerTrain_All Wheel Drive  ...  \
# Cluster                                                                  ...
# 0           0.913793 4.706897  35120.706897                    0.051724  ...
# 1           1.000000 5.181818  94012.818182                    1.000000  ...
# 2           1.000000 4.000000 197890.500000                    1.000000  ...
# 3           1.000000 5.285714  61048.821429                    0.750000  ...
# ...

# %%
sns.scatterplot(x=pca_data[:,0],y=pca_data[:,1],hue=final_kmeans.labels_,s=1000,palette='tab10')
plt.xlabel("PC1")
plt.ylabel("PC2")
# Out:
# Text(0, 0.5, 'PC2')

# %%
data["Cluster"]=final_kmeans.labels_

# %%
data
# Out:
#      Unnamed: 0        Brand                            Model     Accel  \
# 0             0       Tesla     Model 3 Long Range Dual Motor  4.600000
# 1             1  Volkswagen                         ID.3 Pure 10.000000
# 2             2    Polestar                                 2  4.700000
# 3             3         BMW                              iX3   6.800000
# 4             4       Honda                                e   9.500000
# ..          ...          ...                              ...       ...
# 98           98      Nissan                       Ariya 63kWh  7.500000
# 99           99        Audi     e-tron S Sportback 55 quattro  4.500000
# 100         100      Nissan               Ariya e-4ORCE 63kWh  5.900000
# 101         101      Nissan   Ariya e-4ORCE 87kWh Performance  5.100000
# 102         102       Byton                 M-Byte 95 kWh 2WD  7.500000
#
#       TopSpeed      Range  Efficiency  FastCharge  RapidCharge  \
# ...

# %%
segement_profile = data_bool.groupby("Cluster").aggregate('mean')
# Max is used as the affregate the function to get the maximum possible estimate of the pricing

# %%
segement_profile
# Out:
#          Unnamed: 0    Accel   TopSpeed      Range  Efficiency  FastCharge  \
# Cluster
# 0         49.086207 9.124138 153.344828 274.741379  174.034483  316.896552
# 1         57.454545 4.081818 234.636364 428.181818  214.909091  597.272727
# 2         33.500000 2.450000 335.000000 672.500000  214.500000  850.000000
# 3         53.035714 5.807143 193.285714 397.500000  209.428571  540.714286
# 4         55.500000 5.050000 225.000000 443.750000  183.250000  742.500000
#
#          RapidCharge    Seats     PriceEuro  PowerTrain_All Wheel Drive  ...  \
# Cluster                                                                  ...
# 0           0.913793 4.706897  35120.706897                    0.051724  ...
# 1           1.000000 5.181818  94012.818182                    1.000000  ...
# 2           1.000000 4.000000 197890.500000                    1.000000  ...
# 3           1.000000 5.285714  61048.821429                    0.750000  ...
# ...

# %%
segement_profile.insert(8,"BodyType",['SUV','Hatchback','Sedan,Cabrio','SUV','Sedan'])

# %%
segement_profile=segement_profile.drop(['BodyStyle_Cabrio', 'BodyStyle_Hatchback', 'BodyStyle_Liftback',
       'BodyStyle_MPV', 'BodyStyle_Pickup', 'BodyStyle_SPV', 'BodyStyle_SUV',
       'BodyStyle_Sedan', 'BodyStyle_Station'],axis=1)

# %%
segement_profile['Seats']=segement_profile['Seats'].apply('round')

# %%
segement_profile.insert(9,"PowerTrain",['Front Wheel Drive','All Wheel Drive','All Wheel Drive','All Wheel Drive','All Wheel Drive'])

# %%
segement_profile = segement_profile.drop(['PowerTrain_All Wheel Drive', 'PowerTrain_Front Wheel Drive','PowerTrain_Rear Wheel Drive'],axis=1)

# %%
segement_profile.insert(10,"PlugType",['Type 2 CCS','Type 2 CCS','Type 2 CCS','Type 2 CCS','Type 2 CCS'])

# %%
segement_profile=segement_profile.drop(['PlugType_Type 1 CHAdeMO',
       'PlugType_Type 2', 'PlugType_Type 2 CCS', 'PlugType_Type 2 CHAdeMO'],axis=1)

# %%
segement_profile['RapidCharge']=segement_profile['RapidCharge'].apply('round')

# %%
segement_profile
# Out:
#          Unnamed: 0    Accel   TopSpeed      Range  Efficiency  FastCharge  \
# Cluster
# 0         49.086207 9.124138 153.344828 274.741379  174.034483  316.896552
# 1         57.454545 4.081818 234.636364 428.181818  214.909091  597.272727
# 2         33.500000 2.450000 335.000000 672.500000  214.500000  850.000000
# 3         53.035714 5.807143 193.285714 397.500000  209.428571  540.714286
# 4         55.500000 5.050000 225.000000 443.750000  183.250000  742.500000
#
#          RapidCharge    Seats      BodyType         PowerTrain    PlugType  \
# Cluster
# 0           1.000000 5.000000           SUV  Front Wheel Drive  Type 2 CCS
# 1           1.000000 5.000000     Hatchback    All Wheel Drive  Type 2 CCS
# 2           1.000000 4.000000  Sedan,Cabrio    All Wheel Drive  Type 2 CCS
# 3           1.000000 5.000000           SUV    All Wheel Drive  Type 2 CCS
# 4           1.000000 4.000000         Sedan    All Wheel Drive  Type 2 CCS
#
#             PriceEuro
# Cluster
# ...

# %%
X=segement_profile.drop(['Unnamed: 0','BodyType','PowerTrain','PlugType','RapidCharge'],axis=1)

for i in segement_profile.columns:
    n = segement_profile[i].max()
    def scale(x):
        return(x/n)
    try:
        X[i]=X[i].apply(scale)
    except:
        continue

fig,axes = plt.subplots(3,2)
fig1 = sns.barplot(x=X.iloc[0].index, y=X.iloc[0],ax=axes[0,0])
fig1.set_xticklabels(X.columns, rotation='vertical')
fig2 = sns.barplot(x=X.iloc[1].index, y=X.iloc[1],ax=axes[0,1])
fig2.set_xticklabels(X.columns, rotation='vertical')
fig3 = sns.barplot(x=X.iloc[2].index, y=X.iloc[2],ax=axes[1,0])
fig3.set_xticklabels(X.columns, rotation='vertical')
fig4 = sns.barplot(x=X.iloc[3].index, y=X.iloc[3],ax=axes[1,1])
fig4.set_xticklabels(X.columns, rotation='vertical')
fig5 = sns.barplot(x=X.iloc[4].index, y=X.iloc[4],ax=axes[2,0])
fig5.set_xticklabels(X.columns, rotation='vertical')
plt.rcParams["figure.figsize"] = (50,25)

# %%
sns.heatmap(X.corr(),annot=True,cmap='BuGn')
# Out:
# <AxesSubplot:>
